# %% [markdown]
# # **Guest List**
# If you could invite anyone, living or deceased, to dinner, who would
# you invite? Make a list that includes at least three people you’d like to invite to dinner.
# Then use your list to print a message to each person, inviting them to dinner.

# %%
# Here's how to solve this question:

guest_list = ['Elon Musk', 'Xi Jinping', 'Cristiano Ronaldo']

# Sending the first set of invitations
print(f"Dear {guest_list[0].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[1].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[2].title()} I’d be honored to have you at dinner!\n")

# One guest can't come
print("Unfortunately, Xi Jinping can’t make it to dinner.")

# Replace the guest who can't come
guest_list[1] = 'Jeff Bezos'

# Sending new invitations
print(f"\nDear {guest_list[0].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[1].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[2].title()} I’d be honored to have you at dinner!\n")

# Bigger table found
print("We found a bigger table! Now we can invite 3 more people.\n")

# Adding more guests
guest_list.append('Tom Cruise')
guest_list.insert(2, 'Robert Downey Jr.')
guest_list.insert(3, 'Abraham Lincoln')

# Sending invitations to everyone in the updated guest list
print(f"Dear {guest_list[0].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[1].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[2].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[3].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[4].title()} I’d be honored to have you at dinner!")
print(f"Dear {guest_list[5].title()} I’d be honored to have you at dinner!\n")

# Shrinking guest list
print("Unfortunately, I can only invite two people for dinner\n")

# Informing the guests who are not invited now
print(f"Dear {guest_list[5]}, unfortunately, I can only invite two people for dinner, so I won’t be able to invite you.")
print(f"Dear {guest_list[4]}, unfortunately, I can only invite two people for dinner, so I won’t be able to invite you.")
print(f"Dear {guest_list[3]}, unfortunately, I can only invite two people for dinner, so I won’t be able to invite you.")
print(f"Dear {guest_list[2]}, unfortunately, I can only invite two people for dinner, so I won’t be able to invite you.")

# Removing guests one by one
guest_list.pop(5)
guest_list.pop(4)
guest_list.pop(3)
guest_list.pop(2)

# Confirming the two guests who are still invited
print(f"\nDear {guest_list[0]} I’m glad to let you know that you’re still invited to dinner. See you soon!")
print(f"Dear {guest_list[1]} I’m glad to let you know that you’re still invited to dinner. See you soon!")

# Removing the last two guests to make the list empty
del guest_list[0]
del guest_list[0]

# Checking the list is now empty
print(f"\nFinal guest list: {guest_list}")


print(f"\nI’m inviting {len(guest_list)} people to dinner.")
# Out:
# Dear Elon Musk I’d be honored to have you at dinner!
# Dear Xi Jinping I’d be honored to have you at dinner!
# Dear Cristiano Ronaldo I’d be honored to have you at dinner!
#
# Unfortunately, Xi Jinping can’t make it to dinner.
#
# Dear Elon Musk I’d be honored to have you at dinner!
# Dear Jeff Bezos I’d be honored to have you at dinner!
# Dear Cristiano Ronaldo I’d be honored to have you at dinner!
#
# We found a bigger table! Now we can invite 3 more people.
#
# Dear Elon Musk I’d be honored to have you at dinner!
# Dear Jeff Bezos I’d be honored to have you at dinner!
# Dear Robert Downey Jr. I’d be honored to have you at dinner!
# Dear Abraham Lincoln I’d be honored to have you at dinner!
# Dear Cristiano Ronaldo I’d be honored to have you at dinner!
# Dear Tom Cruise I’d be honored to have you at dinner!
#
# Unfortunately, I can only invite two people for dinner
#
# Dear Tom Cruise, unfortunately, I can only invite two people for dinner, so I won’t be able to invite you.
# ...
